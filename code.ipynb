# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(-5, 5, 30)
y = np.linspace(-15, 7, 30)

# %%
plt.plot(x, y)

# %%
print("Inch'Allah je vais reussir")
# Out:
# Inch'Allah je vais reussir
